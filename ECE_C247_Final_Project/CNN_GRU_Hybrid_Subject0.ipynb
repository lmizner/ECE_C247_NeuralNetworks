# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, ELU
from keras.layers import Conv2D, GRU, LSTM, BatchNormalization, MaxPool2D, Reshape
from keras.utils import to_categorical
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.initializers import lecun_uniform
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# cd drive/MyDrive/'Colab Notebooks'/CNN_Project/

# %%
## Loading and visualizing the data

## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that

# 2115 trials with each trial being a 22 x 1000 dimension data point
# Try to classify each movement by it's type/label (0, 1, 2, 3 - left, right, foot, tongue)
# Cue onset arm left - 0
# Cue onset arm right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

# Plotted for channel 8 of 22 channels
ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])




# Only using first 500 timesteps because from the chart we can see everything to the right
# of 500 looks like noise, while the left looks like better information
# Can also keep all 1000 if you want (optional preprocessing step)
# Too long of a time duration can be too much for RNN/LSTM, so it helps to reduce time duration
# Out:
# (2115, 22, 1000)

# %%
indices = np.where(person_train_valid == 0.0)[0]

subject_0_X_train_data = X_train_valid[indices]
subject_0_y_train_data = y_train_valid[indices]

print ('Training/Valid data shape: {}'.format(subject_0_X_train_data.shape))
print ('Training/Valid data shape: {}'.format(subject_0_y_train_data.shape))
# Out:
# Training/Valid data shape: (237, 22, 1000)
# Training/Valid data shape: (237,)

# %%
## Preprocessing the dataset
# ONLY TAKING FIRST 500 datapoints of the 1000
X_train_valid_prep = subject_0_X_train_data[:,:,0:500]
X_test_prep = X_test[:,:,0:500]

print(X_train_valid_prep.shape)
print(subject_0_y_train_data.shape)
print(X_test_prep.shape)
print(y_test.shape)
# Out:
# (237, 22, 500)
# (237,)
# (443, 22, 500)
# (443,)

# %%
## Random splitting and reshaping the data

# 500 for validation, rest for training
# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(237, 100, replace=False)
ind_train = np.array(list(set(range(237)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (137, 22, 500)
# Shape of validation set: (100, 22, 500)
# Shape of training labels: (137,)
# Shape of validation labels: (100,)
# Shape of training labels after categorical conversion: (137, 4)
# Shape of validation labels after categorical conversion: (100, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (137, 22, 500, 1)
# Shape of validation set after adding width info: (100, 22, 500, 1)
# Shape of test set after adding width info: (443, 22, 500, 1)
# Shape of training set after dimension reshaping: (137, 500, 1, 22)
# Shape of validation set after dimension reshaping: (100, 500, 1, 22)
# Shape of test set after dimension reshaping: (443, 500, 1, 22)

# %%
# Building the CNN/GRU Hybrid model using sequential class
hybrid_cnn_gru_model = Sequential()

# Conv. block 1
hybrid_cnn_gru_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu', input_shape=(500,1,22)))
hybrid_cnn_gru_model.add(MaxPool2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.55))

# Conv. block 2
hybrid_cnn_gru_model.add(Conv2D(filters=50, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_gru_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.55))

# Conv. block 3
hybrid_cnn_gru_model.add(Conv2D(filters=100, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_gru_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.55))

# Conv. block 4
hybrid_cnn_gru_model.add(Conv2D(filters=200, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_gru_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_gru_model.add(BatchNormalization())
hybrid_cnn_gru_model.add(Dropout(0.55))

# FC+LSTM layers
hybrid_cnn_gru_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_gru_model.add(Dense((40))) # FC layer with 100 units
hybrid_cnn_gru_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_gru_model.add(GRU(30, dropout=0.20, recurrent_dropout=0.0, input_shape=(40,1), kernel_regularizer=L1L2(l1=0, l2=0.015), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_gru_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_gru_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 500, 1, 25)        5525
#
#  max_pooling2d_8 (MaxPoolin  (None, 167, 1, 25)        0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 167, 1, 25)        100
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 167, 1, 25)        0
#
#  conv2d_9 (Conv2D)           (None, 167, 1, 50)        12550
#
#  max_pooling2d_9 (MaxPoolin  (None, 56, 1, 50)         0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 56, 1, 50)         200
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 56, 1, 50)         0
#
#  conv2d_10 (Conv2D)          (None, 56, 1, 100)        50100
#
#  max_pooling2d_10 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_10 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 19, 1, 100)        0
#
#  conv2d_11 (Conv2D)          (None, 19, 1, 200)        200200
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 1, 200)         0
#  ng2D)
#
#  batch_normalization_11 (Ba  (None, 7, 1, 200)         800
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 7, 1, 200)         0
#
#  flatten_2 (Flatten)         (None, 1400)              0
#
#  dense_4 (Dense)             (None, 40)                56040
#
#  reshape_2 (Reshape)         (None, 40, 1)             0
#
#  gru_2 (GRU)                 (None, 30)                2970
#
#  dense_5 (Dense)             (None, 4)                 124
#
# =================================================================
# Total params: 329009 (1.26 MB)
# Trainable params: 328259 (1.25 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________

# %%
# Model parameters MODEL PARAMETERS
learning_rate = 0.00075
epochs = 150
hybrid_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate, decay = 0.001)

# %%
# Compiling the model COMPILING THE MODEL
hybrid_cnn_gru_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_gru_model_results = hybrid_cnn_gru_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 149ms/step - loss: 5.1989 - accuracy: 0.2555 - val_loss: 4.9924 - val_accuracy: 0.2900
# Epoch 2/150
# 3/3 [==============================] - 0s 41ms/step - loss: 4.9521 - accuracy: 0.2409 - val_loss: 4.7764 - val_accuracy: 0.2900
# Epoch 3/150
# 3/3 [==============================] - 0s 39ms/step - loss: 4.7404 - accuracy: 0.2628 - val_loss: 4.5744 - val_accuracy: 0.2700
# Epoch 4/150
# 3/3 [==============================] - 0s 41ms/step - loss: 4.5272 - accuracy: 0.2847 - val_loss: 4.3894 - val_accuracy: 0.3000
# Epoch 5/150
# 3/3 [==============================] - 0s 40ms/step - loss: 4.3288 - accuracy: 0.3212 - val_loss: 4.2198 - val_accuracy: 0.2600
# Epoch 6/150
# 3/3 [==============================] - 0s 40ms/step - loss: 4.1612 - accuracy: 0.3796 - val_loss: 4.0651 - val_accuracy: 0.2500
# Epoch 7/150
# 3/3 [==============================] - 0s 40ms/step - loss: 4.0147 - accuracy: 0.2993 - val_loss: 3.9255 - val_accuracy: 0.2500
# Epoch 8/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.8570 - accuracy: 0.4161 - val_loss: 3.8007 - val_accuracy: 0.2500
# Epoch 9/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.7349 - accuracy: 0.3431 - val_loss: 3.6864 - val_accuracy: 0.2500
# Epoch 10/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.5928 - accuracy: 0.4088 - val_loss: 3.5886 - val_accuracy: 0.2800
# Epoch 11/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.4821 - accuracy: 0.3942 - val_loss: 3.5048 - val_accuracy: 0.2900
# Epoch 12/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.3933 - accuracy: 0.3723 - val_loss: 3.4264 - val_accuracy: 0.2900
# Epoch 13/150
# 3/3 [==============================] - 0s 41ms/step - loss: 3.3141 - accuracy: 0.3723 - val_loss: 3.3570 - val_accuracy: 0.2900
# Epoch 14/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.2307 - accuracy: 0.4015 - val_loss: 3.2942 - val_accuracy: 0.3100
# Epoch 15/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.1648 - accuracy: 0.3577 - val_loss: 3.2472 - val_accuracy: 0.3100
# Epoch 16/150
# 3/3 [==============================] - 0s 41ms/step - loss: 3.0857 - accuracy: 0.3650 - val_loss: 3.2098 - val_accuracy: 0.3200
# Epoch 17/150
# 3/3 [==============================] - 0s 40ms/step - loss: 3.0424 - accuracy: 0.4088 - val_loss: 3.1733 - val_accuracy: 0.2900
# Epoch 18/150
# 3/3 [==============================] - 0s 39ms/step - loss: 2.9662 - accuracy: 0.4088 - val_loss: 3.1350 - val_accuracy: 0.2600
# Epoch 19/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.9152 - accuracy: 0.4745 - val_loss: 3.1036 - val_accuracy: 0.2900
# Epoch 20/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.8938 - accuracy: 0.4672 - val_loss: 3.0658 - val_accuracy: 0.3200
# Epoch 21/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.8368 - accuracy: 0.4307 - val_loss: 3.0174 - val_accuracy: 0.3100
# Epoch 22/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.8181 - accuracy: 0.4161 - val_loss: 2.9754 - val_accuracy: 0.3200
# Epoch 23/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.7884 - accuracy: 0.4672 - val_loss: 2.9441 - val_accuracy: 0.3300
# Epoch 24/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.7148 - accuracy: 0.4818 - val_loss: 2.9205 - val_accuracy: 0.3300
# Epoch 25/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.6986 - accuracy: 0.4818 - val_loss: 2.9026 - val_accuracy: 0.3300
# Epoch 26/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.6267 - accuracy: 0.4599 - val_loss: 2.8789 - val_accuracy: 0.3400
# Epoch 27/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.6309 - accuracy: 0.4672 - val_loss: 2.8539 - val_accuracy: 0.3300
# Epoch 28/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.5211 - accuracy: 0.4964 - val_loss: 2.8286 - val_accuracy: 0.3200
# Epoch 29/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.5651 - accuracy: 0.4088 - val_loss: 2.8102 - val_accuracy: 0.3000
# Epoch 30/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.5090 - accuracy: 0.4599 - val_loss: 2.7957 - val_accuracy: 0.3000
# Epoch 31/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.4770 - accuracy: 0.5109 - val_loss: 2.7848 - val_accuracy: 0.2800
# Epoch 32/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.4819 - accuracy: 0.5474 - val_loss: 2.7825 - val_accuracy: 0.2400
# Epoch 33/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.4140 - accuracy: 0.5255 - val_loss: 2.7869 - val_accuracy: 0.2100
# Epoch 34/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3782 - accuracy: 0.5474 - val_loss: 2.8088 - val_accuracy: 0.2100
# Epoch 35/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3854 - accuracy: 0.5547 - val_loss: 2.8618 - val_accuracy: 0.2400
# Epoch 36/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.3742 - accuracy: 0.4745 - val_loss: 2.9469 - val_accuracy: 0.2400
# Epoch 37/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3217 - accuracy: 0.5328 - val_loss: 3.0155 - val_accuracy: 0.2200
# Epoch 38/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3291 - accuracy: 0.4964 - val_loss: 3.0376 - val_accuracy: 0.2000
# Epoch 39/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3509 - accuracy: 0.4964 - val_loss: 3.0470 - val_accuracy: 0.2000
# Epoch 40/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.2938 - accuracy: 0.5547 - val_loss: 2.9731 - val_accuracy: 0.2000
# Epoch 41/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.2308 - accuracy: 0.5693 - val_loss: 2.9806 - val_accuracy: 0.2100
# Epoch 42/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.2864 - accuracy: 0.5620 - val_loss: 3.0144 - val_accuracy: 0.2300
# Epoch 43/150
# 3/3 [==============================] - 0s 42ms/step - loss: 2.1828 - accuracy: 0.5109 - val_loss: 2.9905 - val_accuracy: 0.2100
# Epoch 44/150
# 3/3 [==============================] - 0s 40ms/step - loss: 2.2325 - accuracy: 0.5547 - val_loss: 3.0187 - val_accuracy: 0.2200
# Epoch 45/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.2048 - accuracy: 0.5547 - val_loss: 3.1417 - val_accuracy: 0.2400
# Epoch 46/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.1873 - accuracy: 0.5328 - val_loss: 3.2167 - val_accuracy: 0.2100
# Epoch 47/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.1714 - accuracy: 0.5985 - val_loss: 3.2253 - val_accuracy: 0.1900
# Epoch 48/150
# 3/3 [==============================] - 0s 42ms/step - loss: 2.1400 - accuracy: 0.5109 - val_loss: 3.1661 - val_accuracy: 0.1800
# Epoch 49/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.0922 - accuracy: 0.5912 - val_loss: 3.2589 - val_accuracy: 0.1600
# Epoch 50/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9819 - accuracy: 0.6934 - val_loss: 3.3128 - val_accuracy: 0.1600
# Epoch 51/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.0433 - accuracy: 0.5912 - val_loss: 3.3155 - val_accuracy: 0.2200
# Epoch 52/150
# 3/3 [==============================] - 0s 41ms/step - loss: 2.0141 - accuracy: 0.6277 - val_loss: 3.2852 - val_accuracy: 0.2400
# Epoch 53/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9688 - accuracy: 0.6642 - val_loss: 3.2423 - val_accuracy: 0.2500
# Epoch 54/150
# 3/3 [==============================] - 0s 42ms/step - loss: 2.0305 - accuracy: 0.6277 - val_loss: 3.2203 - val_accuracy: 0.2500
# Epoch 55/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9272 - accuracy: 0.6423 - val_loss: 3.2789 - val_accuracy: 0.2300
# Epoch 56/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.9465 - accuracy: 0.5985 - val_loss: 3.4251 - val_accuracy: 0.1900
# Epoch 57/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9726 - accuracy: 0.6350 - val_loss: 3.4538 - val_accuracy: 0.2200
# Epoch 58/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9191 - accuracy: 0.5985 - val_loss: 3.3318 - val_accuracy: 0.2200
# Epoch 59/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.9782 - accuracy: 0.6423 - val_loss: 3.2930 - val_accuracy: 0.2600
# Epoch 60/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8861 - accuracy: 0.6642 - val_loss: 3.3294 - val_accuracy: 0.2600
# Epoch 61/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9303 - accuracy: 0.6058 - val_loss: 3.3799 - val_accuracy: 0.3100
# Epoch 62/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8654 - accuracy: 0.6569 - val_loss: 3.3411 - val_accuracy: 0.3400
# Epoch 63/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8904 - accuracy: 0.6569 - val_loss: 3.2425 - val_accuracy: 0.3200
# Epoch 64/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8268 - accuracy: 0.7153 - val_loss: 3.1786 - val_accuracy: 0.3000
# Epoch 65/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9326 - accuracy: 0.5985 - val_loss: 3.1372 - val_accuracy: 0.2900
# Epoch 66/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8969 - accuracy: 0.6277 - val_loss: 3.1045 - val_accuracy: 0.3100
# Epoch 67/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8453 - accuracy: 0.6058 - val_loss: 3.1286 - val_accuracy: 0.3500
# Epoch 68/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.9149 - accuracy: 0.5547 - val_loss: 3.2711 - val_accuracy: 0.3100
# Epoch 69/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8539 - accuracy: 0.6204 - val_loss: 3.3987 - val_accuracy: 0.3100
# Epoch 70/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8399 - accuracy: 0.6350 - val_loss: 3.4207 - val_accuracy: 0.3100
# Epoch 71/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8693 - accuracy: 0.6496 - val_loss: 3.2427 - val_accuracy: 0.3000
# Epoch 72/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8250 - accuracy: 0.6350 - val_loss: 3.1242 - val_accuracy: 0.3100
# Epoch 73/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.8431 - accuracy: 0.6642 - val_loss: 3.0732 - val_accuracy: 0.3000
# Epoch 74/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8029 - accuracy: 0.6642 - val_loss: 3.1072 - val_accuracy: 0.3200
# Epoch 75/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7975 - accuracy: 0.6569 - val_loss: 3.2060 - val_accuracy: 0.2800
# Epoch 76/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7646 - accuracy: 0.7007 - val_loss: 3.2707 - val_accuracy: 0.2900
# Epoch 77/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.8065 - accuracy: 0.7007 - val_loss: 3.3242 - val_accuracy: 0.2700
# Epoch 78/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.7775 - accuracy: 0.6496 - val_loss: 3.2339 - val_accuracy: 0.2800
# Epoch 79/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.6864 - accuracy: 0.7299 - val_loss: 3.2000 - val_accuracy: 0.2600
# Epoch 80/150
# 3/3 [==============================] - 0s 47ms/step - loss: 1.6752 - accuracy: 0.7445 - val_loss: 3.2289 - val_accuracy: 0.2400
# Epoch 81/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.7504 - accuracy: 0.6642 - val_loss: 3.2517 - val_accuracy: 0.2300
# Epoch 82/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6997 - accuracy: 0.7299 - val_loss: 3.2275 - val_accuracy: 0.2800
# Epoch 83/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6982 - accuracy: 0.7299 - val_loss: 3.1568 - val_accuracy: 0.2800
# Epoch 84/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6333 - accuracy: 0.7299 - val_loss: 3.0578 - val_accuracy: 0.3000
# Epoch 85/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.6088 - accuracy: 0.7883 - val_loss: 3.0189 - val_accuracy: 0.3300
# Epoch 86/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6648 - accuracy: 0.7299 - val_loss: 3.0706 - val_accuracy: 0.3200
# Epoch 87/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6640 - accuracy: 0.7372 - val_loss: 3.1258 - val_accuracy: 0.3300
# Epoch 88/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6652 - accuracy: 0.7664 - val_loss: 3.2061 - val_accuracy: 0.3000
# Epoch 89/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6364 - accuracy: 0.7883 - val_loss: 3.2503 - val_accuracy: 0.3100
# Epoch 90/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5833 - accuracy: 0.8175 - val_loss: 3.2134 - val_accuracy: 0.3200
# Epoch 91/150
# 3/3 [==============================] - 0s 41ms/step - loss: 1.5811 - accuracy: 0.7956 - val_loss: 3.2171 - val_accuracy: 0.3100
# Epoch 92/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5723 - accuracy: 0.7664 - val_loss: 3.2324 - val_accuracy: 0.3100
# Epoch 93/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5560 - accuracy: 0.8029 - val_loss: 3.2517 - val_accuracy: 0.3300
# Epoch 94/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5595 - accuracy: 0.7883 - val_loss: 3.2904 - val_accuracy: 0.3300
# Epoch 95/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6158 - accuracy: 0.7664 - val_loss: 3.2059 - val_accuracy: 0.3300
# Epoch 96/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.6163 - accuracy: 0.7664 - val_loss: 3.1821 - val_accuracy: 0.3500
# Epoch 97/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.5835 - accuracy: 0.7591 - val_loss: 3.2183 - val_accuracy: 0.3500
# Epoch 98/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.6366 - accuracy: 0.7518 - val_loss: 3.3035 - val_accuracy: 0.3700
# Epoch 99/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.6151 - accuracy: 0.7445 - val_loss: 3.3802 - val_accuracy: 0.3200
# Epoch 100/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5273 - accuracy: 0.8102 - val_loss: 3.3726 - val_accuracy: 0.3000
# Epoch 101/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5222 - accuracy: 0.7518 - val_loss: 3.2798 - val_accuracy: 0.3200
# Epoch 102/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5550 - accuracy: 0.7956 - val_loss: 3.1901 - val_accuracy: 0.3300
# Epoch 103/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5478 - accuracy: 0.7664 - val_loss: 3.1732 - val_accuracy: 0.3600
# Epoch 104/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5198 - accuracy: 0.7956 - val_loss: 3.2241 - val_accuracy: 0.3700
# Epoch 105/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5402 - accuracy: 0.7445 - val_loss: 3.3000 - val_accuracy: 0.3800
# Epoch 106/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.5505 - accuracy: 0.7664 - val_loss: 3.2971 - val_accuracy: 0.3800
# Epoch 107/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5080 - accuracy: 0.8029 - val_loss: 3.2369 - val_accuracy: 0.3500
# Epoch 108/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4554 - accuracy: 0.8613 - val_loss: 3.1731 - val_accuracy: 0.3500
# Epoch 109/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4569 - accuracy: 0.8175 - val_loss: 3.1409 - val_accuracy: 0.3500
# Epoch 110/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4294 - accuracy: 0.7956 - val_loss: 3.2037 - val_accuracy: 0.3400
# Epoch 111/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4523 - accuracy: 0.8029 - val_loss: 3.2265 - val_accuracy: 0.3200
# Epoch 112/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4892 - accuracy: 0.7445 - val_loss: 3.1733 - val_accuracy: 0.3300
# Epoch 113/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4525 - accuracy: 0.8029 - val_loss: 3.1153 - val_accuracy: 0.3700
# Epoch 114/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4712 - accuracy: 0.7810 - val_loss: 3.1030 - val_accuracy: 0.3300
# Epoch 115/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4605 - accuracy: 0.7956 - val_loss: 3.1706 - val_accuracy: 0.3500
# Epoch 116/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4019 - accuracy: 0.8540 - val_loss: 3.2170 - val_accuracy: 0.3700
# Epoch 117/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3832 - accuracy: 0.8613 - val_loss: 3.1955 - val_accuracy: 0.3800
# Epoch 118/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4428 - accuracy: 0.8321 - val_loss: 3.2181 - val_accuracy: 0.3800
# Epoch 119/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4377 - accuracy: 0.7883 - val_loss: 3.3458 - val_accuracy: 0.3300
# Epoch 120/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4084 - accuracy: 0.8321 - val_loss: 3.3401 - val_accuracy: 0.3400
# Epoch 121/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4950 - accuracy: 0.8175 - val_loss: 3.2064 - val_accuracy: 0.3600
# Epoch 122/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4216 - accuracy: 0.8467 - val_loss: 3.0702 - val_accuracy: 0.3800
# Epoch 123/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4612 - accuracy: 0.7664 - val_loss: 3.0169 - val_accuracy: 0.3600
# Epoch 124/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3936 - accuracy: 0.8613 - val_loss: 3.0289 - val_accuracy: 0.3600
# Epoch 125/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3954 - accuracy: 0.8248 - val_loss: 3.0710 - val_accuracy: 0.3500
# Epoch 126/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4567 - accuracy: 0.8248 - val_loss: 3.0987 - val_accuracy: 0.3500
# Epoch 127/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4295 - accuracy: 0.8102 - val_loss: 3.1041 - val_accuracy: 0.3700
# Epoch 128/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4168 - accuracy: 0.8832 - val_loss: 3.1421 - val_accuracy: 0.3700
# Epoch 129/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4484 - accuracy: 0.7956 - val_loss: 3.1999 - val_accuracy: 0.3800
# Epoch 130/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3871 - accuracy: 0.8613 - val_loss: 3.2130 - val_accuracy: 0.3800
# Epoch 131/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3848 - accuracy: 0.8467 - val_loss: 3.1872 - val_accuracy: 0.3900
# Epoch 132/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3506 - accuracy: 0.8832 - val_loss: 3.1415 - val_accuracy: 0.3600
# Epoch 133/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3664 - accuracy: 0.8467 - val_loss: 3.1369 - val_accuracy: 0.3700
# Epoch 134/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.3771 - accuracy: 0.8467 - val_loss: 3.2427 - val_accuracy: 0.3900
# Epoch 135/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4286 - accuracy: 0.8248 - val_loss: 3.2668 - val_accuracy: 0.3600
# Epoch 136/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4284 - accuracy: 0.8175 - val_loss: 3.2796 - val_accuracy: 0.3600
# Epoch 137/150
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3310 - accuracy: 0.8540 - val_loss: 3.3272 - val_accuracy: 0.3600
# Epoch 138/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.2871 - accuracy: 0.8905 - val_loss: 3.3248 - val_accuracy: 0.3400
# Epoch 139/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5034 - accuracy: 0.8175 - val_loss: 3.3743 - val_accuracy: 0.3500
# Epoch 140/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3937 - accuracy: 0.8394 - val_loss: 3.4041 - val_accuracy: 0.3500
# Epoch 141/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3534 - accuracy: 0.8686 - val_loss: 3.4539 - val_accuracy: 0.3400
# Epoch 142/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3620 - accuracy: 0.8613 - val_loss: 3.4709 - val_accuracy: 0.3900
# Epoch 143/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3721 - accuracy: 0.8175 - val_loss: 3.4567 - val_accuracy: 0.3800
# Epoch 144/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4471 - accuracy: 0.7664 - val_loss: 3.3242 - val_accuracy: 0.3800
# Epoch 145/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.3166 - accuracy: 0.8759 - val_loss: 3.0330 - val_accuracy: 0.3700
# Epoch 146/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3489 - accuracy: 0.8540 - val_loss: 2.9832 - val_accuracy: 0.4100
# Epoch 147/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.4149 - accuracy: 0.8321 - val_loss: 2.9738 - val_accuracy: 0.4000
# Epoch 148/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3537 - accuracy: 0.8686 - val_loss: 3.0125 - val_accuracy: 0.3800
# Epoch 149/150
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3395 - accuracy: 0.8686 - val_loss: 3.1634 - val_accuracy: 0.3900
# Epoch 150/150
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4170 - accuracy: 0.7956 - val_loss: 3.2440 - val_accuracy: 0.3200

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_gru_model_results.history['accuracy'])
plt.plot(hybrid_cnn_gru_model_results.history['val_accuracy'])
plt.title('Hybrid CNN/GRU model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_gru_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_gru_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN/GRU model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the basic CNN model - using the model from the last epoch (Must get 70% or higher for full credit)

hybrid_score = hybrid_cnn_gru_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hyrbid CNN/GRU model:',hybrid_score[1])
# Out:
# Test accuracy of the hyrbid CNN/GRU model: 0.3521444797515869

# %% [markdown]
# This is a reasonabley well performing model, the validation accuracy (orange) is closely following the training accuracy (blue), so the model is not overfitting. Similar for the loss plot, the validation(orange) is following closely with the training loss (blue) and seems to be converging (going toward zero), may be better to train for more epochs to see further convergence.
#
# U shaped curve for the loss means we are overfitting.
