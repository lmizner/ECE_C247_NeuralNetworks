# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, ELU
from keras.layers import Conv2D, LSTM, BatchNormalization, MaxPool2D, Reshape
from keras.utils import to_categorical
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.initializers import lecun_uniform
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# cd drive/MyDrive/'Colab Notebooks'/CNN_Project/

# %%
## Loading and visualizing the data

## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that

# 2115 trials with each trial being a 22 x 1000 dimension data point
# Try to classify each movement by it's type/label (0, 1, 2, 3 - left, right, foot, tongue)
# Cue onset arm left - 0
# Cue onset arm right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

# Plotted for channel 8 of 22 channels
ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])




# Only using first 500 timesteps because from the chart we can see everything to the right
# of 500 looks like noise, while the left looks like better information
# Can also keep all 1000 if you want (optional preprocessing step)
# Too long of a time duration can be too much for RNN/LSTM, so it helps to reduce time duration
# Out:
# (2115, 22, 1000)

# %%
## Preprocessing the dataset
# ONLY TAKING FIRST 500 datapoints of the 1000
X_train_valid_prep = X_train_valid[:,:,0:500]
X_test_prep = X_test[:,:,0:500]




print(X_train_valid_prep.shape)
print(y_train_valid.shape)
print(X_test_prep.shape)
print(y_test.shape)



## Random splitting and reshaping the data

# 500 for validation, rest for training
# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# (2115, 22, 500)
# (2115,)
# (443, 22, 500)
# (443,)
# Shape of training set: (1615, 22, 500)
# Shape of validation set: (500, 22, 500)
# Shape of training labels: (1615,)
# Shape of validation labels: (500,)
# Shape of training labels after categorical conversion: (1615, 4)
# Shape of validation labels after categorical conversion: (500, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (1615, 22, 500, 1)
# Shape of validation set after adding width info: (500, 22, 500, 1)
# Shape of test set after adding width info: (443, 22, 500, 1)
# Shape of training set after dimension reshaping: (1615, 500, 1, 22)
# Shape of validation set after dimension reshaping: (500, 500, 1, 22)
# Shape of test set after dimension reshaping: (443, 500, 1, 22)

# %%
# Building the CNN model using sequential class
# Building the layers of the CNN model is the sequential package
# Initialize cnn model using sequential block
# MODEL ARCHITECTURE
basic_cnn_model = Sequential()

# First layer requires the shape of the input
# Can you relu activation instead of relu
# Block is being repeated 4 times, but with filter size increase with each layer

# Conv. block 1
basic_cnn_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', kernel_regularizer=L1L2(l1=0, l2=0.015), input_shape=(500,1,22)))
basic_cnn_model.add(MaxPool2D(pool_size=(3,1), padding='same')) # Read the keras documentation
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.55))

# Conv. block 2
basic_cnn_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu'))
basic_cnn_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.55))

# Conv. block 3
basic_cnn_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu'))
basic_cnn_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.55))

# Conv. block 4
basic_cnn_model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu'))
basic_cnn_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.55))


# Full-connected layer with 4 units and softmax activation to obtain probabilities
# Output layer with Softmax activation
basic_cnn_model.add(Flatten()) # Flattens the input
basic_cnn_model.add(Dense(4, kernel_regularizer=L1L2(l1=0, l2=0.015), activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
basic_cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 500, 1, 25)        5525
#
#  max_pooling2d (MaxPooling2  (None, 167, 1, 25)        0
#  D)
#
#  batch_normalization (Batch  (None, 167, 1, 25)        100
#  Normalization)
#
#  dropout (Dropout)           (None, 167, 1, 25)        0
#
#  conv2d_1 (Conv2D)           (None, 167, 1, 50)        12550
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 1, 50)         0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 56, 1, 50)         200
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 56, 1, 50)         0
#
#  conv2d_2 (Conv2D)           (None, 56, 1, 100)        50100
#
#  max_pooling2d_2 (MaxPoolin  (None, 19, 1, 100)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 19, 1, 100)        400
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 19, 1, 100)        0
#
#  conv2d_3 (Conv2D)           (None, 19, 1, 200)        200200
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 1, 200)         0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 7, 1, 200)         800
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 7, 1, 200)         0
#
#  flatten (Flatten)           (None, 1400)              0
#
#  dense (Dense)               (None, 4)                 5604
#
# =================================================================
# Total params: 275479 (1.05 MB)
# Trainable params: 274729 (1.05 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________

# %%
# Model parameters MODEL PARAMETERS
learning_rate = 0.0009
epochs = 100
cnn_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate, decay = 0.001)

# %%
# Compiling the model COMPILING THE MODEL
basic_cnn_model.compile(loss='categorical_crossentropy',
                 optimizer=cnn_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
basic_cnn_model_results = basic_cnn_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 1s 42ms/step - loss: 6.2835 - accuracy: 0.2941 - val_loss: 5.9499 - val_accuracy: 0.3540
# Epoch 2/100
# 26/26 [==============================] - 1s 38ms/step - loss: 5.9962 - accuracy: 0.3467 - val_loss: 5.3580 - val_accuracy: 0.3700
# Epoch 3/100
# 26/26 [==============================] - 1s 38ms/step - loss: 5.7843 - accuracy: 0.3443 - val_loss: 5.3250 - val_accuracy: 0.3720
# Epoch 4/100
# 26/26 [==============================] - 1s 38ms/step - loss: 5.5822 - accuracy: 0.3548 - val_loss: 5.1150 - val_accuracy: 0.3720
# Epoch 5/100
# 26/26 [==============================] - 1s 38ms/step - loss: 5.3494 - accuracy: 0.3647 - val_loss: 4.9758 - val_accuracy: 0.3780
# Epoch 6/100
# 26/26 [==============================] - 1s 39ms/step - loss: 5.1629 - accuracy: 0.3814 - val_loss: 4.8156 - val_accuracy: 0.4140
# Epoch 7/100
# 26/26 [==============================] - 1s 42ms/step - loss: 4.9384 - accuracy: 0.4105 - val_loss: 4.6483 - val_accuracy: 0.4260
# Epoch 8/100
# 26/26 [==============================] - 1s 41ms/step - loss: 4.7898 - accuracy: 0.4105 - val_loss: 4.5779 - val_accuracy: 0.3840
# Epoch 9/100
# 26/26 [==============================] - 1s 44ms/step - loss: 4.5949 - accuracy: 0.4353 - val_loss: 4.4355 - val_accuracy: 0.3640
# Epoch 10/100
# 26/26 [==============================] - 1s 44ms/step - loss: 4.4983 - accuracy: 0.4266 - val_loss: 4.2932 - val_accuracy: 0.3940
# Epoch 11/100
# 26/26 [==============================] - 1s 47ms/step - loss: 4.3138 - accuracy: 0.4502 - val_loss: 4.1332 - val_accuracy: 0.4140
# Epoch 12/100
# 26/26 [==============================] - 1s 44ms/step - loss: 4.1501 - accuracy: 0.4960 - val_loss: 4.0064 - val_accuracy: 0.4260
# Epoch 13/100
# 26/26 [==============================] - 1s 41ms/step - loss: 4.0357 - accuracy: 0.4656 - val_loss: 3.8623 - val_accuracy: 0.4800
# Epoch 14/100
# 26/26 [==============================] - 1s 43ms/step - loss: 3.8534 - accuracy: 0.5084 - val_loss: 3.8035 - val_accuracy: 0.4780
# Epoch 15/100
# 26/26 [==============================] - 1s 40ms/step - loss: 3.7736 - accuracy: 0.5059 - val_loss: 3.7030 - val_accuracy: 0.4560
# Epoch 16/100
# 26/26 [==============================] - 1s 44ms/step - loss: 3.6551 - accuracy: 0.4867 - val_loss: 3.6172 - val_accuracy: 0.4580
# Epoch 17/100
# 26/26 [==============================] - 1s 42ms/step - loss: 3.5209 - accuracy: 0.5084 - val_loss: 3.5304 - val_accuracy: 0.4280
# Epoch 18/100
# 26/26 [==============================] - 1s 40ms/step - loss: 3.4764 - accuracy: 0.5022 - val_loss: 3.6566 - val_accuracy: 0.3560
# Epoch 19/100
# 26/26 [==============================] - 1s 42ms/step - loss: 3.3338 - accuracy: 0.5381 - val_loss: 3.4877 - val_accuracy: 0.3920
# Epoch 20/100
# 26/26 [==============================] - 1s 42ms/step - loss: 3.2272 - accuracy: 0.5331 - val_loss: 3.3044 - val_accuracy: 0.4240
# Epoch 21/100
# 26/26 [==============================] - 1s 45ms/step - loss: 3.1656 - accuracy: 0.5220 - val_loss: 3.1722 - val_accuracy: 0.5000
# Epoch 22/100
# 26/26 [==============================] - 1s 42ms/step - loss: 3.0621 - accuracy: 0.5375 - val_loss: 3.2226 - val_accuracy: 0.4280
# Epoch 23/100
# 26/26 [==============================] - 1s 44ms/step - loss: 2.9670 - accuracy: 0.5585 - val_loss: 3.0315 - val_accuracy: 0.4720
# Epoch 24/100
# 26/26 [==============================] - 1s 43ms/step - loss: 2.9193 - accuracy: 0.5579 - val_loss: 2.9046 - val_accuracy: 0.5340
# Epoch 25/100
# 26/26 [==============================] - 1s 43ms/step - loss: 2.7733 - accuracy: 0.5858 - val_loss: 2.9813 - val_accuracy: 0.4480
# Epoch 26/100
# 26/26 [==============================] - 1s 46ms/step - loss: 2.7184 - accuracy: 0.5783 - val_loss: 2.9796 - val_accuracy: 0.4180
# Epoch 27/100
# 26/26 [==============================] - 1s 45ms/step - loss: 2.6683 - accuracy: 0.5709 - val_loss: 2.8510 - val_accuracy: 0.4340
# Epoch 28/100
# 26/26 [==============================] - 1s 43ms/step - loss: 2.5809 - accuracy: 0.6025 - val_loss: 2.6885 - val_accuracy: 0.5200
# Epoch 29/100
# 26/26 [==============================] - 1s 43ms/step - loss: 2.5144 - accuracy: 0.6000 - val_loss: 2.7326 - val_accuracy: 0.5100
# Epoch 30/100
# 26/26 [==============================] - 1s 42ms/step - loss: 2.4619 - accuracy: 0.5994 - val_loss: 2.5897 - val_accuracy: 0.5240
# Epoch 31/100
# 26/26 [==============================] - 1s 44ms/step - loss: 2.3966 - accuracy: 0.6235 - val_loss: 2.5082 - val_accuracy: 0.5380
# Epoch 32/100
# 26/26 [==============================] - 1s 44ms/step - loss: 2.3423 - accuracy: 0.6204 - val_loss: 2.5975 - val_accuracy: 0.4680
# Epoch 33/100
# 26/26 [==============================] - 1s 45ms/step - loss: 2.3156 - accuracy: 0.6167 - val_loss: 2.4221 - val_accuracy: 0.5220
# Epoch 34/100
# 26/26 [==============================] - 1s 45ms/step - loss: 2.2705 - accuracy: 0.6025 - val_loss: 2.3522 - val_accuracy: 0.5560
# Epoch 35/100
# 26/26 [==============================] - 1s 42ms/step - loss: 2.2256 - accuracy: 0.6149 - val_loss: 2.2824 - val_accuracy: 0.5560
# Epoch 36/100
# 26/26 [==============================] - 1s 41ms/step - loss: 2.1554 - accuracy: 0.6223 - val_loss: 2.2839 - val_accuracy: 0.5500
# Epoch 37/100
# 26/26 [==============================] - 1s 42ms/step - loss: 2.1026 - accuracy: 0.6353 - val_loss: 2.1879 - val_accuracy: 0.5860
# Epoch 38/100
# 26/26 [==============================] - 1s 43ms/step - loss: 2.0491 - accuracy: 0.6489 - val_loss: 2.1589 - val_accuracy: 0.5840
# Epoch 39/100
# 26/26 [==============================] - 1s 41ms/step - loss: 2.0289 - accuracy: 0.6328 - val_loss: 2.1480 - val_accuracy: 0.5620
# Epoch 40/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.9866 - accuracy: 0.6471 - val_loss: 2.0754 - val_accuracy: 0.5760
# Epoch 41/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.9302 - accuracy: 0.6650 - val_loss: 2.0693 - val_accuracy: 0.5760
# Epoch 42/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.8652 - accuracy: 0.6650 - val_loss: 2.1063 - val_accuracy: 0.5280
# Epoch 43/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.8711 - accuracy: 0.6576 - val_loss: 1.9573 - val_accuracy: 0.6220
# Epoch 44/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.8596 - accuracy: 0.6545 - val_loss: 2.0648 - val_accuracy: 0.5460
# Epoch 45/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.8185 - accuracy: 0.6607 - val_loss: 1.9769 - val_accuracy: 0.5920
# Epoch 46/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.7737 - accuracy: 0.6749 - val_loss: 1.9115 - val_accuracy: 0.5860
# Epoch 47/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.7478 - accuracy: 0.6811 - val_loss: 1.8837 - val_accuracy: 0.6140
# Epoch 48/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.7093 - accuracy: 0.6836 - val_loss: 1.8619 - val_accuracy: 0.6140
# Epoch 49/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.6622 - accuracy: 0.6916 - val_loss: 1.8491 - val_accuracy: 0.5900
# Epoch 50/100
# 26/26 [==============================] - 1s 41ms/step - loss: 1.6480 - accuracy: 0.6929 - val_loss: 1.8067 - val_accuracy: 0.5860
# Epoch 51/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.6022 - accuracy: 0.7034 - val_loss: 1.7664 - val_accuracy: 0.6440
# Epoch 52/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.5959 - accuracy: 0.6923 - val_loss: 1.7671 - val_accuracy: 0.5940
# Epoch 53/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.5744 - accuracy: 0.7053 - val_loss: 1.8373 - val_accuracy: 0.5860
# Epoch 54/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.5369 - accuracy: 0.7176 - val_loss: 1.7930 - val_accuracy: 0.5900
# Epoch 55/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.5054 - accuracy: 0.7170 - val_loss: 1.6985 - val_accuracy: 0.6320
# Epoch 56/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.5213 - accuracy: 0.7115 - val_loss: 1.6702 - val_accuracy: 0.6560
# Epoch 57/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.4853 - accuracy: 0.7183 - val_loss: 1.6741 - val_accuracy: 0.6100
# Epoch 58/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.4599 - accuracy: 0.7313 - val_loss: 1.6447 - val_accuracy: 0.6260
# Epoch 59/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.4255 - accuracy: 0.7387 - val_loss: 1.6349 - val_accuracy: 0.6340
# Epoch 60/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.4418 - accuracy: 0.7164 - val_loss: 1.6189 - val_accuracy: 0.6300
# Epoch 61/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.4148 - accuracy: 0.7257 - val_loss: 1.5956 - val_accuracy: 0.6280
# Epoch 62/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.4208 - accuracy: 0.7170 - val_loss: 1.5877 - val_accuracy: 0.6620
# Epoch 63/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.3704 - accuracy: 0.7486 - val_loss: 1.5662 - val_accuracy: 0.6580
# Epoch 64/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.3541 - accuracy: 0.7387 - val_loss: 1.5949 - val_accuracy: 0.6240
# Epoch 65/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.3560 - accuracy: 0.7232 - val_loss: 1.5420 - val_accuracy: 0.6440
# Epoch 66/100
# 26/26 [==============================] - 1s 42ms/step - loss: 1.3395 - accuracy: 0.7393 - val_loss: 1.5602 - val_accuracy: 0.6220
# Epoch 67/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.3264 - accuracy: 0.7300 - val_loss: 1.5510 - val_accuracy: 0.6320
# Epoch 68/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.3101 - accuracy: 0.7517 - val_loss: 1.5205 - val_accuracy: 0.6580
# Epoch 69/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.3014 - accuracy: 0.7399 - val_loss: 1.5503 - val_accuracy: 0.6300
# Epoch 70/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.3132 - accuracy: 0.7387 - val_loss: 1.5980 - val_accuracy: 0.6140
# Epoch 71/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.2927 - accuracy: 0.7406 - val_loss: 1.5158 - val_accuracy: 0.6580
# Epoch 72/100
# 26/26 [==============================] - 1s 43ms/step - loss: 1.2720 - accuracy: 0.7498 - val_loss: 1.5059 - val_accuracy: 0.6660
# Epoch 73/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.2197 - accuracy: 0.7672 - val_loss: 1.4820 - val_accuracy: 0.6660
# Epoch 74/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.2336 - accuracy: 0.7604 - val_loss: 1.4752 - val_accuracy: 0.6440
# Epoch 75/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.2265 - accuracy: 0.7746 - val_loss: 1.4729 - val_accuracy: 0.6620
# Epoch 76/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.2094 - accuracy: 0.7728 - val_loss: 1.4531 - val_accuracy: 0.6560
# Epoch 77/100
# 26/26 [==============================] - 1s 45ms/step - loss: 1.2053 - accuracy: 0.7616 - val_loss: 1.4649 - val_accuracy: 0.6620
# Epoch 78/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.1801 - accuracy: 0.7870 - val_loss: 1.4266 - val_accuracy: 0.6700
# Epoch 79/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.1725 - accuracy: 0.7666 - val_loss: 1.4293 - val_accuracy: 0.6880
# Epoch 80/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.1874 - accuracy: 0.7628 - val_loss: 1.4531 - val_accuracy: 0.6440
# Epoch 81/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.1308 - accuracy: 0.7808 - val_loss: 1.3907 - val_accuracy: 0.6680
# Epoch 82/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.1060 - accuracy: 0.7988 - val_loss: 1.3875 - val_accuracy: 0.6620
# Epoch 83/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.1318 - accuracy: 0.7895 - val_loss: 1.4582 - val_accuracy: 0.6540
# Epoch 84/100
# 26/26 [==============================] - 1s 48ms/step - loss: 1.1193 - accuracy: 0.7913 - val_loss: 1.4134 - val_accuracy: 0.6640
# Epoch 85/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.1013 - accuracy: 0.7882 - val_loss: 1.3736 - val_accuracy: 0.6560
# Epoch 86/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.1202 - accuracy: 0.7920 - val_loss: 1.3923 - val_accuracy: 0.6760
# Epoch 87/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0887 - accuracy: 0.7950 - val_loss: 1.4236 - val_accuracy: 0.6460
# Epoch 88/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0767 - accuracy: 0.7938 - val_loss: 1.4031 - val_accuracy: 0.6600
# Epoch 89/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0870 - accuracy: 0.7975 - val_loss: 1.4136 - val_accuracy: 0.6560
# Epoch 90/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.0413 - accuracy: 0.8186 - val_loss: 1.3824 - val_accuracy: 0.6600
# Epoch 91/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.0657 - accuracy: 0.7975 - val_loss: 1.4158 - val_accuracy: 0.6420
# Epoch 92/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0217 - accuracy: 0.8211 - val_loss: 1.4226 - val_accuracy: 0.6460
# Epoch 93/100
# 26/26 [==============================] - 1s 51ms/step - loss: 1.0458 - accuracy: 0.8167 - val_loss: 1.4327 - val_accuracy: 0.6460
# Epoch 94/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0477 - accuracy: 0.7864 - val_loss: 1.3840 - val_accuracy: 0.6820
# Epoch 95/100
# 26/26 [==============================] - 1s 47ms/step - loss: 1.0186 - accuracy: 0.8080 - val_loss: 1.4257 - val_accuracy: 0.6480
# Epoch 96/100
# 26/26 [==============================] - 1s 47ms/step - loss: 1.0311 - accuracy: 0.7981 - val_loss: 1.3823 - val_accuracy: 0.6560
# Epoch 97/100
# 26/26 [==============================] - 1s 46ms/step - loss: 1.0319 - accuracy: 0.7981 - val_loss: 1.4018 - val_accuracy: 0.6340
# Epoch 98/100
# 26/26 [==============================] - 1s 45ms/step - loss: 1.0466 - accuracy: 0.8043 - val_loss: 1.3612 - val_accuracy: 0.6780
# Epoch 99/100
# 26/26 [==============================] - 1s 44ms/step - loss: 1.0225 - accuracy: 0.8186 - val_loss: 1.3794 - val_accuracy: 0.6640
# Epoch 100/100
# 26/26 [==============================] - 1s 45ms/step - loss: 1.0203 - accuracy: 0.8087 - val_loss: 1.3622 - val_accuracy: 0.6700

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(basic_cnn_model_results.history['accuracy'])
plt.plot(basic_cnn_model_results.history['val_accuracy'])
plt.title('Basic CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(basic_cnn_model_results.history['loss'],'o')
plt.plot(basic_cnn_model_results.history['val_loss'],'o')
plt.title('Basic CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the basic CNN model - using the model from the last epoch (Must get 70% or higher for full credit)

cnn_score = basic_cnn_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.7065462470054626

# %%
# # Save Model
# import pickle

# filename = 'CNN_70_percent.sav'
# pickle.dump(basic_cnn_model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.evaluate(x_test, y_test, verbose=0)
print(result[1])
# Out:
# 0.7065462470054626

# %% [markdown]
# This is a reasonabley well performing model, the validation accuracy (orange) is closely following the training accuracy (blue), so the model is not overfitting. Similar for the loss plot, the validation(orange) is following closely with the training loss (blue) and seems to be converging (going toward zero), may be better to train for more epochs to see further convergence.
