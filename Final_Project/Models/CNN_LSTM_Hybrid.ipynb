# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, ELU
from keras.layers import Conv2D, LSTM, BatchNormalization, MaxPool2D, Reshape
from keras.utils import to_categorical
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.initializers import lecun_uniform
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# cd drive/MyDrive/'Colab Notebooks'/CNN_Project/

# %%
## Loading and visualizing the data

## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that

# 2115 trials with each trial being a 22 x 1000 dimension data point
# Try to classify each movement by it's type/label (0, 1, 2, 3 - left, right, foot, tongue)
# Cue onset arm left - 0
# Cue onset arm right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

# Plotted for channel 8 of 22 channels
ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])




# Only using first 500 timesteps because from the chart we can see everything to the right
# of 500 looks like noise, while the left looks like better information
# Can also keep all 1000 if you want (optional preprocessing step)
# Too long of a time duration can be too much for RNN/LSTM, so it helps to reduce time duration
# Out:
# (2115, 22, 1000)

# %%
## Preprocessing the dataset
# ONLY TAKING FIRST 500 datapoints of the 1000
X_train_valid_prep = X_train_valid[:,:,0:500]
X_test_prep = X_test[:,:,0:500]




print(X_train_valid_prep.shape)
print(y_train_valid.shape)
print(X_test_prep.shape)
print(y_test.shape)



## Random splitting and reshaping the data

# 500 for validation, rest for training
# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# (2115, 22, 500)
# (2115,)
# (443, 22, 500)
# (443,)
# Shape of training set: (1615, 22, 500)
# Shape of validation set: (500, 22, 500)
# Shape of training labels: (1615,)
# Shape of validation labels: (500,)
# Shape of training labels after categorical conversion: (1615, 4)
# Shape of validation labels after categorical conversion: (500, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (1615, 22, 500, 1)
# Shape of validation set after adding width info: (500, 22, 500, 1)
# Shape of test set after adding width info: (443, 22, 500, 1)
# Shape of training set after dimension reshaping: (1615, 500, 1, 22)
# Shape of validation set after dimension reshaping: (500, 500, 1, 22)
# Shape of test set after dimension reshaping: (443, 500, 1, 22)

# %%
# Building the CNN/LSTM Hybrid model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu', input_shape=(500,1,22)))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=50, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 4
hybrid_cnn_lstm_model.add(Conv2D(filters=200, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model.add(LSTM(30, dropout=0.50, recurrent_dropout=0.1, input_shape=(40,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 500, 1, 25)        5525
#
#  max_pooling2d_48 (MaxPooli  (None, 167, 1, 25)        0
#  ng2D)
#
#  batch_normalization_48 (Ba  (None, 167, 1, 25)        100
#  tchNormalization)
#
#  dropout_48 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_49 (Conv2D)          (None, 167, 1, 50)        12550
#
#  max_pooling2d_49 (MaxPooli  (None, 56, 1, 50)         0
#  ng2D)
#
#  batch_normalization_49 (Ba  (None, 56, 1, 50)         200
#  tchNormalization)
#
#  dropout_49 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_50 (Conv2D)          (None, 56, 1, 100)        50100
#
#  max_pooling2d_50 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_50 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
#  dropout_50 (Dropout)        (None, 19, 1, 100)        0
#
#  conv2d_51 (Conv2D)          (None, 19, 1, 200)        200200
#
#  max_pooling2d_51 (MaxPooli  (None, 7, 1, 200)         0
#  ng2D)
#
#  batch_normalization_51 (Ba  (None, 7, 1, 200)         800
#  tchNormalization)
#
#  dropout_51 (Dropout)        (None, 7, 1, 200)         0
#
#  flatten_12 (Flatten)        (None, 1400)              0
#
#  dense_24 (Dense)            (None, 40)                56040
#
#  reshape_12 (Reshape)        (None, 40, 1)             0
#
#  lstm_12 (LSTM)              (None, 30)                3840
#
#  dense_25 (Dense)            (None, 4)                 124
#
# =================================================================
# Total params: 329879 (1.26 MB)
# Trainable params: 329129 (1.26 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________

# %%
# Model parameters MODEL PARAMETERS
learning_rate = 0.00075
epochs = 150
hybrid_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

# %%
# Compiling the model COMPILING THE MODEL
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/150
# 26/26 [==============================] - 2s 55ms/step - loss: 4.4498 - accuracy: 0.2885 - val_loss: 3.7033 - val_accuracy: 0.3100
# Epoch 2/150
# 26/26 [==============================] - 1s 48ms/step - loss: 3.3197 - accuracy: 0.3139 - val_loss: 2.9399 - val_accuracy: 0.3860
# Epoch 3/150
# 26/26 [==============================] - 1s 48ms/step - loss: 2.7644 - accuracy: 0.3505 - val_loss: 2.5498 - val_accuracy: 0.3920
# Epoch 4/150
# 26/26 [==============================] - 1s 49ms/step - loss: 2.4347 - accuracy: 0.3957 - val_loss: 2.2840 - val_accuracy: 0.3980
# Epoch 5/150
# 26/26 [==============================] - 1s 49ms/step - loss: 2.2130 - accuracy: 0.3926 - val_loss: 2.1256 - val_accuracy: 0.3680
# Epoch 6/150
# 26/26 [==============================] - 1s 49ms/step - loss: 2.0369 - accuracy: 0.4279 - val_loss: 1.9970 - val_accuracy: 0.3740
# Epoch 7/150
# 26/26 [==============================] - 1s 49ms/step - loss: 1.9156 - accuracy: 0.4427 - val_loss: 1.8675 - val_accuracy: 0.4180
# Epoch 8/150
# 26/26 [==============================] - 1s 49ms/step - loss: 1.8178 - accuracy: 0.4402 - val_loss: 1.8141 - val_accuracy: 0.4020
# Epoch 9/150
# 26/26 [==============================] - 1s 49ms/step - loss: 1.7549 - accuracy: 0.4316 - val_loss: 1.7671 - val_accuracy: 0.4060
# Epoch 10/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.7097 - accuracy: 0.4390 - val_loss: 1.7342 - val_accuracy: 0.4180
# Epoch 11/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.6501 - accuracy: 0.4483 - val_loss: 1.6477 - val_accuracy: 0.4440
# Epoch 12/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5954 - accuracy: 0.4737 - val_loss: 1.6264 - val_accuracy: 0.4500
# Epoch 13/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5339 - accuracy: 0.4799 - val_loss: 1.6250 - val_accuracy: 0.4040
# Epoch 14/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.5131 - accuracy: 0.4879 - val_loss: 1.6268 - val_accuracy: 0.4340
# Epoch 15/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4898 - accuracy: 0.5084 - val_loss: 1.6421 - val_accuracy: 0.4240
# Epoch 16/150
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4926 - accuracy: 0.4991 - val_loss: 1.5360 - val_accuracy: 0.4880
# Epoch 17/150
# 26/26 [==============================] - 1s 50ms/step - loss: 1.4776 - accuracy: 0.4935 - val_loss: 1.5225 - val_accuracy: 0.4840
# Epoch 18/150
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4574 - accuracy: 0.5022 - val_loss: 1.5197 - val_accuracy: 0.4820
# Epoch 19/150
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4566 - accuracy: 0.5003 - val_loss: 1.5893 - val_accuracy: 0.4300
# Epoch 20/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4345 - accuracy: 0.5108 - val_loss: 1.6540 - val_accuracy: 0.3900
# Epoch 21/150
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4207 - accuracy: 0.5263 - val_loss: 1.5487 - val_accuracy: 0.4540
# Epoch 22/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4312 - accuracy: 0.5053 - val_loss: 1.5778 - val_accuracy: 0.4200
# Epoch 23/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4633 - accuracy: 0.5009 - val_loss: 1.5349 - val_accuracy: 0.4560
# Epoch 24/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.3948 - accuracy: 0.5480 - val_loss: 1.5475 - val_accuracy: 0.4580
# Epoch 25/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.3976 - accuracy: 0.5331 - val_loss: 1.4966 - val_accuracy: 0.4780
# Epoch 26/150
# 26/26 [==============================] - 1s 51ms/step - loss: 1.4142 - accuracy: 0.5276 - val_loss: 1.6664 - val_accuracy: 0.3860
# Epoch 27/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4240 - accuracy: 0.5294 - val_loss: 1.5189 - val_accuracy: 0.4740
# Epoch 28/150
# 26/26 [==============================] - 1s 52ms/step - loss: 1.4214 - accuracy: 0.5375 - val_loss: 1.5846 - val_accuracy: 0.4460
# Epoch 29/150
# 26/26 [==============================] - 1s 53ms/step - loss: 1.4389 - accuracy: 0.5313 - val_loss: 1.5438 - val_accuracy: 0.4560
# Epoch 30/150
# 26/26 [==============================] - 1s 55ms/step - loss: 1.3995 - accuracy: 0.5393 - val_loss: 1.5622 - val_accuracy: 0.4520
# Epoch 31/150
# 26/26 [==============================] - 1s 56ms/step - loss: 1.4081 - accuracy: 0.5467 - val_loss: 1.5421 - val_accuracy: 0.4620
# Epoch 32/150
# 26/26 [==============================] - 1s 57ms/step - loss: 1.3921 - accuracy: 0.5486 - val_loss: 1.5279 - val_accuracy: 0.4780
# Epoch 33/150
# 26/26 [==============================] - 2s 59ms/step - loss: 1.4076 - accuracy: 0.5375 - val_loss: 1.4580 - val_accuracy: 0.5260
# Epoch 34/150
# 26/26 [==============================] - 2s 61ms/step - loss: 1.3736 - accuracy: 0.5505 - val_loss: 1.4768 - val_accuracy: 0.5080
# Epoch 35/150
# 26/26 [==============================] - 2s 62ms/step - loss: 1.3977 - accuracy: 0.5461 - val_loss: 1.5363 - val_accuracy: 0.4700
# Epoch 36/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3856 - accuracy: 0.5622 - val_loss: 1.5116 - val_accuracy: 0.4780
# Epoch 37/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.4165 - accuracy: 0.5387 - val_loss: 1.5419 - val_accuracy: 0.4520
# Epoch 38/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3802 - accuracy: 0.5622 - val_loss: 1.6241 - val_accuracy: 0.4380
# Epoch 39/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.4121 - accuracy: 0.5585 - val_loss: 1.5504 - val_accuracy: 0.4640
# Epoch 40/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.3731 - accuracy: 0.5641 - val_loss: 1.5891 - val_accuracy: 0.4660
# Epoch 41/150
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3452 - accuracy: 0.5746 - val_loss: 1.4746 - val_accuracy: 0.5220
# Epoch 42/150
# 26/26 [==============================] - 2s 73ms/step - loss: 1.3777 - accuracy: 0.5529 - val_loss: 1.5469 - val_accuracy: 0.4700
# Epoch 43/150
# 26/26 [==============================] - 2s 74ms/step - loss: 1.3937 - accuracy: 0.5461 - val_loss: 1.4919 - val_accuracy: 0.5100
# Epoch 44/150
# 26/26 [==============================] - 2s 75ms/step - loss: 1.3794 - accuracy: 0.5641 - val_loss: 1.4659 - val_accuracy: 0.5280
# Epoch 45/150
# 26/26 [==============================] - 2s 74ms/step - loss: 1.3609 - accuracy: 0.5690 - val_loss: 1.5708 - val_accuracy: 0.4680
# Epoch 46/150
# 26/26 [==============================] - 2s 73ms/step - loss: 1.3686 - accuracy: 0.5820 - val_loss: 1.5646 - val_accuracy: 0.4780
# Epoch 47/150
# 26/26 [==============================] - 2s 77ms/step - loss: 1.3733 - accuracy: 0.5802 - val_loss: 1.5411 - val_accuracy: 0.5100
# Epoch 48/150
# 26/26 [==============================] - 2s 78ms/step - loss: 1.3568 - accuracy: 0.5783 - val_loss: 1.7083 - val_accuracy: 0.4260
# Epoch 49/150
# 26/26 [==============================] - 2s 78ms/step - loss: 1.3981 - accuracy: 0.5808 - val_loss: 1.5437 - val_accuracy: 0.5240
# Epoch 50/150
# 26/26 [==============================] - 2s 78ms/step - loss: 1.3910 - accuracy: 0.5777 - val_loss: 1.5122 - val_accuracy: 0.5440
# Epoch 51/150
# 26/26 [==============================] - 2s 78ms/step - loss: 1.3782 - accuracy: 0.5808 - val_loss: 1.6279 - val_accuracy: 0.4460
# Epoch 52/150
# 26/26 [==============================] - 2s 77ms/step - loss: 1.3472 - accuracy: 0.5864 - val_loss: 1.6557 - val_accuracy: 0.4640
# Epoch 53/150
# 26/26 [==============================] - 2s 77ms/step - loss: 1.3644 - accuracy: 0.5833 - val_loss: 1.5952 - val_accuracy: 0.4760
# Epoch 54/150
# 26/26 [==============================] - 2s 77ms/step - loss: 1.3706 - accuracy: 0.5981 - val_loss: 1.5763 - val_accuracy: 0.5000
# Epoch 55/150
# 26/26 [==============================] - 2s 76ms/step - loss: 1.3760 - accuracy: 0.5913 - val_loss: 1.5830 - val_accuracy: 0.4880
# Epoch 56/150
# 26/26 [==============================] - 2s 76ms/step - loss: 1.4158 - accuracy: 0.5591 - val_loss: 1.5810 - val_accuracy: 0.5140
# Epoch 57/150
# 26/26 [==============================] - 2s 74ms/step - loss: 1.3969 - accuracy: 0.6000 - val_loss: 1.5024 - val_accuracy: 0.5280
# Epoch 58/150
# 26/26 [==============================] - 2s 75ms/step - loss: 1.3843 - accuracy: 0.5709 - val_loss: 1.5122 - val_accuracy: 0.5360
# Epoch 59/150
# 26/26 [==============================] - 2s 74ms/step - loss: 1.3613 - accuracy: 0.6043 - val_loss: 1.5125 - val_accuracy: 0.5400
# Epoch 60/150
# 26/26 [==============================] - 2s 74ms/step - loss: 1.3606 - accuracy: 0.6050 - val_loss: 1.5936 - val_accuracy: 0.5320
# Epoch 61/150
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3672 - accuracy: 0.6087 - val_loss: 1.6599 - val_accuracy: 0.4540
# Epoch 62/150
# 26/26 [==============================] - 2s 70ms/step - loss: 1.3868 - accuracy: 0.5932 - val_loss: 1.5258 - val_accuracy: 0.5340
# Epoch 63/150
# 26/26 [==============================] - 2s 70ms/step - loss: 1.3612 - accuracy: 0.6062 - val_loss: 1.5295 - val_accuracy: 0.5160
# Epoch 64/150
# 26/26 [==============================] - 2s 70ms/step - loss: 1.3331 - accuracy: 0.6105 - val_loss: 1.4882 - val_accuracy: 0.5680
# Epoch 65/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.4055 - accuracy: 0.5994 - val_loss: 1.6232 - val_accuracy: 0.4820
# Epoch 66/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.4038 - accuracy: 0.5926 - val_loss: 1.6210 - val_accuracy: 0.4880
# Epoch 67/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.3630 - accuracy: 0.6241 - val_loss: 1.5585 - val_accuracy: 0.5220
# Epoch 68/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3384 - accuracy: 0.6272 - val_loss: 1.6444 - val_accuracy: 0.4920
# Epoch 69/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3937 - accuracy: 0.6074 - val_loss: 1.5563 - val_accuracy: 0.5220
# Epoch 70/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3749 - accuracy: 0.6155 - val_loss: 1.5444 - val_accuracy: 0.5680
# Epoch 71/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3893 - accuracy: 0.6080 - val_loss: 1.5120 - val_accuracy: 0.5600
# Epoch 72/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3655 - accuracy: 0.6421 - val_loss: 1.5916 - val_accuracy: 0.5580
# Epoch 73/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3845 - accuracy: 0.6365 - val_loss: 1.5188 - val_accuracy: 0.5880
# Epoch 74/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3568 - accuracy: 0.6563 - val_loss: 1.5348 - val_accuracy: 0.5700
# Epoch 75/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3459 - accuracy: 0.6669 - val_loss: 1.4536 - val_accuracy: 0.6080
# Epoch 76/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3570 - accuracy: 0.6440 - val_loss: 1.5106 - val_accuracy: 0.5900
# Epoch 77/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3783 - accuracy: 0.6607 - val_loss: 1.5164 - val_accuracy: 0.6020
# Epoch 78/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3120 - accuracy: 0.6985 - val_loss: 1.5159 - val_accuracy: 0.5920
# Epoch 79/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3193 - accuracy: 0.6743 - val_loss: 1.6192 - val_accuracy: 0.5800
# Epoch 80/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3567 - accuracy: 0.6675 - val_loss: 1.4903 - val_accuracy: 0.6320
# Epoch 81/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3538 - accuracy: 0.6854 - val_loss: 1.4701 - val_accuracy: 0.5880
# Epoch 82/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3259 - accuracy: 0.6854 - val_loss: 1.5238 - val_accuracy: 0.6080
# Epoch 83/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3384 - accuracy: 0.6706 - val_loss: 1.4707 - val_accuracy: 0.6300
# Epoch 84/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3209 - accuracy: 0.6811 - val_loss: 1.5045 - val_accuracy: 0.6080
# Epoch 85/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3006 - accuracy: 0.7022 - val_loss: 1.4951 - val_accuracy: 0.6180
# Epoch 86/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3696 - accuracy: 0.6613 - val_loss: 1.4629 - val_accuracy: 0.6100
# Epoch 87/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2999 - accuracy: 0.7090 - val_loss: 1.4959 - val_accuracy: 0.6240
# Epoch 88/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3446 - accuracy: 0.6824 - val_loss: 1.5430 - val_accuracy: 0.6100
# Epoch 89/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3684 - accuracy: 0.6625 - val_loss: 1.5494 - val_accuracy: 0.5860
# Epoch 90/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3390 - accuracy: 0.6774 - val_loss: 1.4716 - val_accuracy: 0.6080
# Epoch 91/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3619 - accuracy: 0.6737 - val_loss: 1.5465 - val_accuracy: 0.6060
# Epoch 92/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2945 - accuracy: 0.7040 - val_loss: 1.4723 - val_accuracy: 0.6240
# Epoch 93/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3174 - accuracy: 0.6991 - val_loss: 1.4635 - val_accuracy: 0.6320
# Epoch 94/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3288 - accuracy: 0.6892 - val_loss: 1.4129 - val_accuracy: 0.6640
# Epoch 95/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.2978 - accuracy: 0.7077 - val_loss: 1.4561 - val_accuracy: 0.6220
# Epoch 96/150
# 26/26 [==============================] - 2s 71ms/step - loss: 1.3198 - accuracy: 0.6954 - val_loss: 1.4692 - val_accuracy: 0.6300
# Epoch 97/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2955 - accuracy: 0.7022 - val_loss: 1.4651 - val_accuracy: 0.6460
# Epoch 98/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2724 - accuracy: 0.7214 - val_loss: 1.4881 - val_accuracy: 0.6180
# Epoch 99/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3233 - accuracy: 0.7003 - val_loss: 1.4981 - val_accuracy: 0.6160
# Epoch 100/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.2886 - accuracy: 0.7133 - val_loss: 1.4870 - val_accuracy: 0.5840
# Epoch 101/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3020 - accuracy: 0.7164 - val_loss: 1.4372 - val_accuracy: 0.6340
# Epoch 102/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.3181 - accuracy: 0.7003 - val_loss: 1.4689 - val_accuracy: 0.6460
# Epoch 103/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2955 - accuracy: 0.7189 - val_loss: 1.5321 - val_accuracy: 0.6060
# Epoch 104/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3328 - accuracy: 0.6941 - val_loss: 1.4490 - val_accuracy: 0.6740
# Epoch 105/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3077 - accuracy: 0.7108 - val_loss: 1.5076 - val_accuracy: 0.6480
# Epoch 106/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2698 - accuracy: 0.7232 - val_loss: 1.4150 - val_accuracy: 0.6560
# Epoch 107/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3029 - accuracy: 0.7146 - val_loss: 1.5142 - val_accuracy: 0.6180
# Epoch 108/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.3060 - accuracy: 0.7245 - val_loss: 1.4772 - val_accuracy: 0.6340
# Epoch 109/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2976 - accuracy: 0.7164 - val_loss: 1.4300 - val_accuracy: 0.6560
# Epoch 110/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2971 - accuracy: 0.7139 - val_loss: 1.4978 - val_accuracy: 0.6420
# Epoch 111/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3158 - accuracy: 0.7108 - val_loss: 1.5118 - val_accuracy: 0.6120
# Epoch 112/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3131 - accuracy: 0.7053 - val_loss: 1.4563 - val_accuracy: 0.6480
# Epoch 113/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2704 - accuracy: 0.7368 - val_loss: 1.4028 - val_accuracy: 0.6920
# Epoch 114/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2747 - accuracy: 0.7269 - val_loss: 1.4306 - val_accuracy: 0.6460
# Epoch 115/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2667 - accuracy: 0.7220 - val_loss: 1.4959 - val_accuracy: 0.6540
# Epoch 116/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2492 - accuracy: 0.7523 - val_loss: 1.3829 - val_accuracy: 0.6820
# Epoch 117/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2997 - accuracy: 0.7096 - val_loss: 1.4273 - val_accuracy: 0.6640
# Epoch 118/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2602 - accuracy: 0.7331 - val_loss: 1.4158 - val_accuracy: 0.6660
# Epoch 119/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2876 - accuracy: 0.7170 - val_loss: 1.3907 - val_accuracy: 0.6760
# Epoch 120/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2690 - accuracy: 0.7350 - val_loss: 1.4350 - val_accuracy: 0.6460
# Epoch 121/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2828 - accuracy: 0.7393 - val_loss: 1.4879 - val_accuracy: 0.6440
# Epoch 122/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2595 - accuracy: 0.7424 - val_loss: 1.4409 - val_accuracy: 0.6640
# Epoch 123/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2810 - accuracy: 0.7368 - val_loss: 1.4227 - val_accuracy: 0.6820
# Epoch 124/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2755 - accuracy: 0.7430 - val_loss: 1.5703 - val_accuracy: 0.6280
# Epoch 125/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2898 - accuracy: 0.7412 - val_loss: 1.4420 - val_accuracy: 0.6720
# Epoch 126/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2741 - accuracy: 0.7412 - val_loss: 1.4849 - val_accuracy: 0.6480
# Epoch 127/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.3028 - accuracy: 0.7307 - val_loss: 1.4502 - val_accuracy: 0.6580
# Epoch 128/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.2757 - accuracy: 0.7437 - val_loss: 1.4346 - val_accuracy: 0.6780
# Epoch 129/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.2578 - accuracy: 0.7517 - val_loss: 1.3947 - val_accuracy: 0.6840
# Epoch 130/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2502 - accuracy: 0.7474 - val_loss: 1.4192 - val_accuracy: 0.6980
# Epoch 131/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2782 - accuracy: 0.7424 - val_loss: 1.4395 - val_accuracy: 0.6720
# Epoch 132/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.2948 - accuracy: 0.7300 - val_loss: 1.5443 - val_accuracy: 0.6280
# Epoch 133/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.2634 - accuracy: 0.7350 - val_loss: 1.5137 - val_accuracy: 0.6340
# Epoch 134/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2283 - accuracy: 0.7666 - val_loss: 1.3977 - val_accuracy: 0.6840
# Epoch 135/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2253 - accuracy: 0.7628 - val_loss: 1.4061 - val_accuracy: 0.6840
# Epoch 136/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2642 - accuracy: 0.7424 - val_loss: 1.4636 - val_accuracy: 0.6760
# Epoch 137/150
# 26/26 [==============================] - 2s 69ms/step - loss: 1.3304 - accuracy: 0.7245 - val_loss: 1.4940 - val_accuracy: 0.6480
# Epoch 138/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.3099 - accuracy: 0.7325 - val_loss: 1.4508 - val_accuracy: 0.6760
# Epoch 139/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.2627 - accuracy: 0.7486 - val_loss: 1.4351 - val_accuracy: 0.6860
# Epoch 140/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.2725 - accuracy: 0.7443 - val_loss: 1.4705 - val_accuracy: 0.6520
# Epoch 141/150
# 26/26 [==============================] - 2s 67ms/step - loss: 1.2276 - accuracy: 0.7591 - val_loss: 1.5215 - val_accuracy: 0.6460
# Epoch 142/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2472 - accuracy: 0.7492 - val_loss: 1.4021 - val_accuracy: 0.7000
# Epoch 143/150
# 26/26 [==============================] - 2s 66ms/step - loss: 1.2411 - accuracy: 0.7542 - val_loss: 1.4058 - val_accuracy: 0.7060
# Epoch 144/150
# 26/26 [==============================] - 2s 65ms/step - loss: 1.2213 - accuracy: 0.7721 - val_loss: 1.4984 - val_accuracy: 0.6500
# Epoch 145/150
# 26/26 [==============================] - 2s 68ms/step - loss: 1.2853 - accuracy: 0.7412 - val_loss: 1.4222 - val_accuracy: 0.6740
# Epoch 146/150
# 26/26 [==============================] - 2s 72ms/step - loss: 1.2335 - accuracy: 0.7635 - val_loss: 1.5220 - val_accuracy: 0.6400
# Epoch 147/150
# 26/26 [==============================] - 2s 88ms/step - loss: 1.2446 - accuracy: 0.7474 - val_loss: 1.4055 - val_accuracy: 0.6940
# Epoch 148/150
# 26/26 [==============================] - 2s 86ms/step - loss: 1.2572 - accuracy: 0.7542 - val_loss: 1.4779 - val_accuracy: 0.6640
# Epoch 149/150
# 26/26 [==============================] - 2s 95ms/step - loss: 1.2566 - accuracy: 0.7424 - val_loss: 1.4213 - val_accuracy: 0.6760
# Epoch 150/150
# 26/26 [==============================] - 2s 89ms/step - loss: 1.2557 - accuracy: 0.7548 - val_loss: 1.4042 - val_accuracy: 0.7000

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN/LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN/LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the basic CNN model - using the model from the last epoch (Must get 70% or higher for full credit)

hybrid_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hyrbid CNN/LSTM model:',hybrid_score[1])
# Out:
# Test accuracy of the hyrbid CNN/LSTM model: 0.7246049642562866

# %%
# Save Model
import pickle

filename = 'CNN_LSTM_Hybrid.sav'
pickle.dump(hybrid_cnn_lstm_model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.evaluate(x_test, y_test, verbose=0)
print(result[1])
# Out:
# 0.7246049642562866

# %% [markdown]
# This is a reasonabley well performing model, the validation accuracy (orange) is closely following the training accuracy (blue), so the model is not overfitting. Similar for the loss plot, the validation(orange) is following closely with the training loss (blue) and seems to be converging (going toward zero), may be better to train for more epochs to see further convergence.
#
# U shaped curve for the loss means we are overfitting.
