# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, ELU
from keras.layers import Conv2D, LSTM, BatchNormalization, MaxPool2D, Reshape
from keras.utils import to_categorical
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.initializers import lecun_uniform
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# cd drive/MyDrive/'Colab Notebooks'/CNN_Project/

# %%
## Loading and visualizing the data

## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that

# 2115 trials with each trial being a 22 x 1000 dimension data point
# Try to classify each movement by it's type/label (0, 1, 2, 3 - left, right, foot, tongue)
# Cue onset arm left - 0
# Cue onset arm right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

# Plotted for channel 8 of 22 channels
ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])




# Only using first 500 timesteps because from the chart we can see everything to the right
# of 500 looks like noise, while the left looks like better information
# Can also keep all 1000 if you want (optional preprocessing step)
# Too long of a time duration can be too much for RNN/LSTM, so it helps to reduce time duration
# Out:
# (2115, 22, 1000)

# %%
indices = np.where(person_train_valid == 0.0)[0]

subject_0_X_train_data = X_train_valid[indices]
subject_0_y_train_data = y_train_valid[indices]

print ('Training/Valid data shape: {}'.format(subject_0_X_train_data.shape))
print ('Training/Valid data shape: {}'.format(subject_0_y_train_data.shape))
# Out:
# Training/Valid data shape: (237, 22, 1000)
# Training/Valid data shape: (237,)

# %%
## Preprocessing the dataset
# ONLY TAKING FIRST 500 datapoints of the 1000
X_train_valid_prep = subject_0_X_train_data[:,:,0:500]
X_test_prep = X_test[:,:,0:500]

print(X_train_valid_prep.shape)
print(subject_0_y_train_data.shape)
print(X_test_prep.shape)
print(y_test.shape)
# Out:
# (237, 22, 500)
# (237,)
# (443, 22, 500)
# (443,)

# %%
## Random splitting and reshaping the data

# 500 for validation, rest for training
# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(237, 100, replace=False)
ind_train = np.array(list(set(range(237)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (137, 22, 500)
# Shape of validation set: (100, 22, 500)
# Shape of training labels: (137,)
# Shape of validation labels: (100,)
# Shape of training labels after categorical conversion: (137, 4)
# Shape of validation labels after categorical conversion: (100, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (137, 22, 500, 1)
# Shape of validation set after adding width info: (100, 22, 500, 1)
# Shape of test set after adding width info: (443, 22, 500, 1)
# Shape of training set after dimension reshaping: (137, 500, 1, 22)
# Shape of validation set after dimension reshaping: (100, 500, 1, 22)
# Shape of test set after dimension reshaping: (443, 500, 1, 22)

# %%
# Building the CNN/LSTM Hybrid model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', kernel_regularizer=L1L2(l1=0, l2=0.015), activation='elu', input_shape=(500,1,22)))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=50, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# Conv. block 4
hybrid_cnn_lstm_model.add(Conv2D(filters=200, kernel_size=(10,1), kernel_regularizer=L1L2(l1=0, l2=0.015), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPool2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.55))

# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model.add(LSTM(30, dropout=0.50, recurrent_dropout=0.10, input_shape=(40,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 500, 1, 25)        5525
#
#  max_pooling2d_12 (MaxPooli  (None, 167, 1, 25)        0
#  ng2D)
#
#  batch_normalization_12 (Ba  (None, 167, 1, 25)        100
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_13 (Conv2D)          (None, 167, 1, 50)        12550
#
#  max_pooling2d_13 (MaxPooli  (None, 56, 1, 50)         0
#  ng2D)
#
#  batch_normalization_13 (Ba  (None, 56, 1, 50)         200
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_14 (Conv2D)          (None, 56, 1, 100)        50100
#
#  max_pooling2d_14 (MaxPooli  (None, 19, 1, 100)        0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 19, 1, 100)        400
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 19, 1, 100)        0
#
#  conv2d_15 (Conv2D)          (None, 19, 1, 200)        200200
#
#  max_pooling2d_15 (MaxPooli  (None, 7, 1, 200)         0
#  ng2D)
#
#  batch_normalization_15 (Ba  (None, 7, 1, 200)         800
#  tchNormalization)
#
#  dropout_15 (Dropout)        (None, 7, 1, 200)         0
#
#  flatten_3 (Flatten)         (None, 1400)              0
#
#  dense_6 (Dense)             (None, 40)                56040
#
#  reshape_3 (Reshape)         (None, 40, 1)             0
#
#  lstm_3 (LSTM)               (None, 30)                3840
#
#  dense_7 (Dense)             (None, 4)                 124
#
# =================================================================
# Total params: 329879 (1.26 MB)
# Trainable params: 329129 (1.26 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________

# %%
# Model parameters MODEL PARAMETERS
learning_rate = 0.00075
epochs = 150
hybrid_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

# %%
# Compiling the model COMPILING THE MODEL
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 130ms/step - loss: 5.2259 - accuracy: 0.2263 - val_loss: 5.0958 - val_accuracy: 0.2800
# Epoch 2/150
# 3/3 [==============================] - 0s 48ms/step - loss: 5.0828 - accuracy: 0.2263 - val_loss: 4.9724 - val_accuracy: 0.2500
# Epoch 3/150
# 3/3 [==============================] - 0s 47ms/step - loss: 4.9461 - accuracy: 0.2628 - val_loss: 4.8631 - val_accuracy: 0.2800
# Epoch 4/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.8126 - accuracy: 0.2701 - val_loss: 4.7584 - val_accuracy: 0.2800
# Epoch 5/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.7050 - accuracy: 0.2993 - val_loss: 4.6586 - val_accuracy: 0.2600
# Epoch 6/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.5850 - accuracy: 0.3431 - val_loss: 4.5594 - val_accuracy: 0.2400
# Epoch 7/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.5217 - accuracy: 0.2628 - val_loss: 4.4630 - val_accuracy: 0.2400
# Epoch 8/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.3946 - accuracy: 0.3431 - val_loss: 4.3677 - val_accuracy: 0.2500
# Epoch 9/150
# 3/3 [==============================] - 0s 49ms/step - loss: 4.3068 - accuracy: 0.3358 - val_loss: 4.2770 - val_accuracy: 0.2400
# Epoch 10/150
# 3/3 [==============================] - 0s 48ms/step - loss: 4.2110 - accuracy: 0.3504 - val_loss: 4.1893 - val_accuracy: 0.2100
# Epoch 11/150
# 3/3 [==============================] - 0s 49ms/step - loss: 4.1225 - accuracy: 0.3212 - val_loss: 4.1056 - val_accuracy: 0.1900
# Epoch 12/150
# 3/3 [==============================] - 0s 49ms/step - loss: 4.0002 - accuracy: 0.4015 - val_loss: 4.0267 - val_accuracy: 0.1800
# Epoch 13/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.9657 - accuracy: 0.3431 - val_loss: 3.9531 - val_accuracy: 0.2700
# Epoch 14/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.8724 - accuracy: 0.3796 - val_loss: 3.8855 - val_accuracy: 0.2500
# Epoch 15/150
# 3/3 [==============================] - 0s 48ms/step - loss: 3.8274 - accuracy: 0.3285 - val_loss: 3.8220 - val_accuracy: 0.2900
# Epoch 16/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.7401 - accuracy: 0.3869 - val_loss: 3.7607 - val_accuracy: 0.2900
# Epoch 17/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.6699 - accuracy: 0.3504 - val_loss: 3.7034 - val_accuracy: 0.2800
# Epoch 18/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.6018 - accuracy: 0.3942 - val_loss: 3.6489 - val_accuracy: 0.2600
# Epoch 19/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.5429 - accuracy: 0.3869 - val_loss: 3.5962 - val_accuracy: 0.2700
# Epoch 20/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.4966 - accuracy: 0.4234 - val_loss: 3.5453 - val_accuracy: 0.2800
# Epoch 21/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.4250 - accuracy: 0.3796 - val_loss: 3.4999 - val_accuracy: 0.2900
# Epoch 22/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.4166 - accuracy: 0.3869 - val_loss: 3.4625 - val_accuracy: 0.3000
# Epoch 23/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.3680 - accuracy: 0.3723 - val_loss: 3.4236 - val_accuracy: 0.3200
# Epoch 24/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.3003 - accuracy: 0.4307 - val_loss: 3.3855 - val_accuracy: 0.3400
# Epoch 25/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.2723 - accuracy: 0.3869 - val_loss: 3.3475 - val_accuracy: 0.3100
# Epoch 26/150
# 3/3 [==============================] - 0s 46ms/step - loss: 3.2072 - accuracy: 0.4088 - val_loss: 3.3112 - val_accuracy: 0.3300
# Epoch 27/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.1639 - accuracy: 0.4015 - val_loss: 3.2801 - val_accuracy: 0.3400
# Epoch 28/150
# 3/3 [==============================] - 0s 47ms/step - loss: 3.1107 - accuracy: 0.5182 - val_loss: 3.2589 - val_accuracy: 0.3000
# Epoch 29/150
# 3/3 [==============================] - 0s 61ms/step - loss: 3.1056 - accuracy: 0.4380 - val_loss: 3.2437 - val_accuracy: 0.2700
# Epoch 30/150
# 3/3 [==============================] - 0s 48ms/step - loss: 3.0801 - accuracy: 0.3869 - val_loss: 3.2274 - val_accuracy: 0.2900
# Epoch 31/150
# 3/3 [==============================] - 0s 49ms/step - loss: 3.0665 - accuracy: 0.4234 - val_loss: 3.2023 - val_accuracy: 0.3300
# Epoch 32/150
# 3/3 [==============================] - 0s 49ms/step - loss: 3.0054 - accuracy: 0.3942 - val_loss: 3.1803 - val_accuracy: 0.3100
# Epoch 33/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.9338 - accuracy: 0.5036 - val_loss: 3.1581 - val_accuracy: 0.2900
# Epoch 34/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.9274 - accuracy: 0.4891 - val_loss: 3.1387 - val_accuracy: 0.2800
# Epoch 35/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.9161 - accuracy: 0.4380 - val_loss: 3.1234 - val_accuracy: 0.2600
# Epoch 36/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.8511 - accuracy: 0.5036 - val_loss: 3.1078 - val_accuracy: 0.2800
# Epoch 37/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.8203 - accuracy: 0.4745 - val_loss: 3.0981 - val_accuracy: 0.3000
# Epoch 38/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.7993 - accuracy: 0.4526 - val_loss: 3.0815 - val_accuracy: 0.3200
# Epoch 39/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.8282 - accuracy: 0.4599 - val_loss: 3.0601 - val_accuracy: 0.3300
# Epoch 40/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.7498 - accuracy: 0.5036 - val_loss: 3.0444 - val_accuracy: 0.3100
# Epoch 41/150
# 3/3 [==============================] - 0s 52ms/step - loss: 2.7043 - accuracy: 0.4964 - val_loss: 3.0466 - val_accuracy: 0.2700
# Epoch 42/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.7215 - accuracy: 0.4891 - val_loss: 3.0508 - val_accuracy: 0.3100
# Epoch 43/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.7412 - accuracy: 0.4453 - val_loss: 3.0510 - val_accuracy: 0.3200
# Epoch 44/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.6795 - accuracy: 0.4964 - val_loss: 3.0445 - val_accuracy: 0.2900
# Epoch 45/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.6503 - accuracy: 0.5182 - val_loss: 3.0367 - val_accuracy: 0.2700
# Epoch 46/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.6049 - accuracy: 0.5182 - val_loss: 3.0416 - val_accuracy: 0.3200
# Epoch 47/150
# 3/3 [==============================] - 0s 52ms/step - loss: 2.6330 - accuracy: 0.4964 - val_loss: 3.0419 - val_accuracy: 0.3300
# Epoch 48/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.6230 - accuracy: 0.4891 - val_loss: 3.0298 - val_accuracy: 0.2800
# Epoch 49/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.6159 - accuracy: 0.5328 - val_loss: 3.0331 - val_accuracy: 0.2600
# Epoch 50/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.5611 - accuracy: 0.5255 - val_loss: 3.0137 - val_accuracy: 0.2600
# Epoch 51/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.5600 - accuracy: 0.5328 - val_loss: 2.9826 - val_accuracy: 0.2900
# Epoch 52/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.5253 - accuracy: 0.5109 - val_loss: 3.0640 - val_accuracy: 0.3300
# Epoch 53/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.5542 - accuracy: 0.4964 - val_loss: 3.1077 - val_accuracy: 0.3100
# Epoch 54/150
# 3/3 [==============================] - 0s 52ms/step - loss: 2.5194 - accuracy: 0.5547 - val_loss: 3.0633 - val_accuracy: 0.2900
# Epoch 55/150
# 3/3 [==============================] - 0s 67ms/step - loss: 2.5227 - accuracy: 0.5401 - val_loss: 3.0081 - val_accuracy: 0.2800
# Epoch 56/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.4684 - accuracy: 0.5255 - val_loss: 3.0256 - val_accuracy: 0.2600
# Epoch 57/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.5183 - accuracy: 0.5328 - val_loss: 3.0566 - val_accuracy: 0.2600
# Epoch 58/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.4705 - accuracy: 0.4964 - val_loss: 3.1146 - val_accuracy: 0.2700
# Epoch 59/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.4873 - accuracy: 0.4891 - val_loss: 3.1498 - val_accuracy: 0.2600
# Epoch 60/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3949 - accuracy: 0.5620 - val_loss: 3.1682 - val_accuracy: 0.2800
# Epoch 61/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.4132 - accuracy: 0.5182 - val_loss: 3.1991 - val_accuracy: 0.2800
# Epoch 62/150
# 3/3 [==============================] - 0s 52ms/step - loss: 2.4269 - accuracy: 0.5839 - val_loss: 3.1970 - val_accuracy: 0.2800
# Epoch 63/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.4067 - accuracy: 0.5182 - val_loss: 3.1472 - val_accuracy: 0.2900
# Epoch 64/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3468 - accuracy: 0.5474 - val_loss: 3.0970 - val_accuracy: 0.2800
# Epoch 65/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3553 - accuracy: 0.5328 - val_loss: 3.0677 - val_accuracy: 0.2900
# Epoch 66/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3090 - accuracy: 0.5693 - val_loss: 3.0860 - val_accuracy: 0.2600
# Epoch 67/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3205 - accuracy: 0.5255 - val_loss: 3.1662 - val_accuracy: 0.2400
# Epoch 68/150
# 3/3 [==============================] - 0s 48ms/step - loss: 2.2681 - accuracy: 0.6131 - val_loss: 3.2607 - val_accuracy: 0.2400
# Epoch 69/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2993 - accuracy: 0.5109 - val_loss: 3.2928 - val_accuracy: 0.2600
# Epoch 70/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2718 - accuracy: 0.5620 - val_loss: 3.2896 - val_accuracy: 0.2700
# Epoch 71/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.2943 - accuracy: 0.5693 - val_loss: 3.2400 - val_accuracy: 0.2400
# Epoch 72/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.3071 - accuracy: 0.5474 - val_loss: 3.0807 - val_accuracy: 0.2800
# Epoch 73/150
# 3/3 [==============================] - 0s 67ms/step - loss: 2.2119 - accuracy: 0.6423 - val_loss: 3.0670 - val_accuracy: 0.3000
# Epoch 74/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.2180 - accuracy: 0.5839 - val_loss: 3.1379 - val_accuracy: 0.3000
# Epoch 75/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.2342 - accuracy: 0.5620 - val_loss: 3.2612 - val_accuracy: 0.2700
# Epoch 76/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2007 - accuracy: 0.5839 - val_loss: 3.4267 - val_accuracy: 0.2400
# Epoch 77/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.1902 - accuracy: 0.6058 - val_loss: 3.4426 - val_accuracy: 0.2400
# Epoch 78/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.1031 - accuracy: 0.6058 - val_loss: 3.4245 - val_accuracy: 0.2600
# Epoch 79/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.0901 - accuracy: 0.6642 - val_loss: 3.3832 - val_accuracy: 0.2600
# Epoch 80/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2168 - accuracy: 0.5693 - val_loss: 3.3957 - val_accuracy: 0.2700
# Epoch 81/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.1579 - accuracy: 0.6204 - val_loss: 3.4538 - val_accuracy: 0.2600
# Epoch 82/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.1323 - accuracy: 0.6423 - val_loss: 3.4283 - val_accuracy: 0.2500
# Epoch 83/150
# 3/3 [==============================] - 0s 65ms/step - loss: 2.0934 - accuracy: 0.6277 - val_loss: 3.2556 - val_accuracy: 0.2600
# Epoch 84/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.1121 - accuracy: 0.6058 - val_loss: 3.1657 - val_accuracy: 0.2800
# Epoch 85/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.1658 - accuracy: 0.6131 - val_loss: 3.0987 - val_accuracy: 0.3300
# Epoch 86/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.1441 - accuracy: 0.6277 - val_loss: 3.0976 - val_accuracy: 0.3300
# Epoch 87/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.0501 - accuracy: 0.6350 - val_loss: 3.1363 - val_accuracy: 0.3000
# Epoch 88/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.1060 - accuracy: 0.6204 - val_loss: 3.1889 - val_accuracy: 0.3200
# Epoch 89/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.1125 - accuracy: 0.6277 - val_loss: 3.3219 - val_accuracy: 0.3000
# Epoch 90/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.1421 - accuracy: 0.5912 - val_loss: 3.3719 - val_accuracy: 0.3000
# Epoch 91/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.1147 - accuracy: 0.6204 - val_loss: 3.3561 - val_accuracy: 0.2800
# Epoch 92/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.0037 - accuracy: 0.7153 - val_loss: 3.3567 - val_accuracy: 0.2800
# Epoch 93/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.0916 - accuracy: 0.5766 - val_loss: 3.3871 - val_accuracy: 0.2600
# Epoch 94/150
# 3/3 [==============================] - 0s 50ms/step - loss: 2.0831 - accuracy: 0.6496 - val_loss: 3.3910 - val_accuracy: 0.2700
# Epoch 95/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.9737 - accuracy: 0.6642 - val_loss: 3.3703 - val_accuracy: 0.2800
# Epoch 96/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.9936 - accuracy: 0.6423 - val_loss: 3.3715 - val_accuracy: 0.2700
# Epoch 97/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.0674 - accuracy: 0.6204 - val_loss: 3.4003 - val_accuracy: 0.2700
# Epoch 98/150
# 3/3 [==============================] - 0s 51ms/step - loss: 2.0467 - accuracy: 0.6715 - val_loss: 3.3773 - val_accuracy: 0.2500
# Epoch 99/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.9267 - accuracy: 0.7226 - val_loss: 3.3611 - val_accuracy: 0.2700
# Epoch 100/150
# 3/3 [==============================] - 0s 49ms/step - loss: 2.0043 - accuracy: 0.6569 - val_loss: 3.3503 - val_accuracy: 0.2400
# Epoch 101/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.9540 - accuracy: 0.6569 - val_loss: 3.3660 - val_accuracy: 0.2300
# Epoch 102/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.9573 - accuracy: 0.6715 - val_loss: 3.3965 - val_accuracy: 0.2400
# Epoch 103/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.9380 - accuracy: 0.6569 - val_loss: 3.3889 - val_accuracy: 0.2400
# Epoch 104/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8791 - accuracy: 0.6788 - val_loss: 3.3798 - val_accuracy: 0.2400
# Epoch 105/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8927 - accuracy: 0.6715 - val_loss: 3.3329 - val_accuracy: 0.2600
# Epoch 106/150
# 3/3 [==============================] - 0s 48ms/step - loss: 1.8533 - accuracy: 0.7299 - val_loss: 3.2530 - val_accuracy: 0.2900
# Epoch 107/150
# 3/3 [==============================] - 0s 63ms/step - loss: 1.9006 - accuracy: 0.7445 - val_loss: 3.2220 - val_accuracy: 0.2900
# Epoch 108/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8512 - accuracy: 0.6788 - val_loss: 3.2268 - val_accuracy: 0.3400
# Epoch 109/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8541 - accuracy: 0.6788 - val_loss: 3.1857 - val_accuracy: 0.3700
# Epoch 110/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8896 - accuracy: 0.7153 - val_loss: 3.1054 - val_accuracy: 0.3800
# Epoch 111/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.8649 - accuracy: 0.6423 - val_loss: 3.1081 - val_accuracy: 0.4100
# Epoch 112/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8129 - accuracy: 0.7007 - val_loss: 3.1441 - val_accuracy: 0.3800
# Epoch 113/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8752 - accuracy: 0.6642 - val_loss: 3.1850 - val_accuracy: 0.3700
# Epoch 114/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7728 - accuracy: 0.7080 - val_loss: 3.2383 - val_accuracy: 0.3500
# Epoch 115/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7605 - accuracy: 0.7591 - val_loss: 3.2630 - val_accuracy: 0.3500
# Epoch 116/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.8277 - accuracy: 0.7080 - val_loss: 3.2982 - val_accuracy: 0.3300
# Epoch 117/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8046 - accuracy: 0.7007 - val_loss: 3.4046 - val_accuracy: 0.3100
# Epoch 118/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8414 - accuracy: 0.7299 - val_loss: 3.3941 - val_accuracy: 0.3300
# Epoch 119/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7400 - accuracy: 0.7372 - val_loss: 3.3432 - val_accuracy: 0.3500
# Epoch 120/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6869 - accuracy: 0.7956 - val_loss: 3.3275 - val_accuracy: 0.3500
# Epoch 121/150
# 3/3 [==============================] - 0s 49ms/step - loss: 1.7380 - accuracy: 0.7080 - val_loss: 3.3173 - val_accuracy: 0.3500
# Epoch 122/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7593 - accuracy: 0.7153 - val_loss: 3.3167 - val_accuracy: 0.3100
# Epoch 123/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7534 - accuracy: 0.7591 - val_loss: 3.1903 - val_accuracy: 0.3500
# Epoch 124/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8321 - accuracy: 0.7007 - val_loss: 3.1742 - val_accuracy: 0.3400
# Epoch 125/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8220 - accuracy: 0.6861 - val_loss: 3.2242 - val_accuracy: 0.3100
# Epoch 126/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8402 - accuracy: 0.6934 - val_loss: 3.2778 - val_accuracy: 0.3100
# Epoch 127/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8342 - accuracy: 0.7226 - val_loss: 3.3362 - val_accuracy: 0.3300
# Epoch 128/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7791 - accuracy: 0.7153 - val_loss: 3.3730 - val_accuracy: 0.3200
# Epoch 129/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8597 - accuracy: 0.6861 - val_loss: 3.3377 - val_accuracy: 0.3300
# Epoch 130/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7983 - accuracy: 0.7007 - val_loss: 3.2428 - val_accuracy: 0.3600
# Epoch 131/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.8465 - accuracy: 0.6642 - val_loss: 3.1675 - val_accuracy: 0.3500
# Epoch 132/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7373 - accuracy: 0.7737 - val_loss: 3.1774 - val_accuracy: 0.3600
# Epoch 133/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7618 - accuracy: 0.7080 - val_loss: 3.1819 - val_accuracy: 0.3500
# Epoch 134/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.7176 - accuracy: 0.7518 - val_loss: 3.2416 - val_accuracy: 0.3500
# Epoch 135/150
# 3/3 [==============================] - 0s 65ms/step - loss: 1.7031 - accuracy: 0.7518 - val_loss: 3.3052 - val_accuracy: 0.3600
# Epoch 136/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6405 - accuracy: 0.7737 - val_loss: 3.3915 - val_accuracy: 0.3300
# Epoch 137/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6970 - accuracy: 0.7883 - val_loss: 3.4906 - val_accuracy: 0.3200
# Epoch 138/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6638 - accuracy: 0.8102 - val_loss: 3.5224 - val_accuracy: 0.3000
# Epoch 139/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7138 - accuracy: 0.8029 - val_loss: 3.4982 - val_accuracy: 0.3000
# Epoch 140/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6675 - accuracy: 0.8029 - val_loss: 3.4479 - val_accuracy: 0.3400
# Epoch 141/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6296 - accuracy: 0.8102 - val_loss: 3.3419 - val_accuracy: 0.3600
# Epoch 142/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.5841 - accuracy: 0.7883 - val_loss: 3.3163 - val_accuracy: 0.3600
# Epoch 143/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6864 - accuracy: 0.7664 - val_loss: 3.2818 - val_accuracy: 0.3600
# Epoch 144/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6757 - accuracy: 0.7226 - val_loss: 3.2479 - val_accuracy: 0.3500
# Epoch 145/150
# 3/3 [==============================] - 0s 50ms/step - loss: 1.6685 - accuracy: 0.7737 - val_loss: 3.2266 - val_accuracy: 0.3600
# Epoch 146/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6150 - accuracy: 0.7810 - val_loss: 3.2231 - val_accuracy: 0.3400
# Epoch 147/150
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6947 - accuracy: 0.7445 - val_loss: 3.2355 - val_accuracy: 0.3400
# Epoch 148/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6088 - accuracy: 0.8029 - val_loss: 3.2619 - val_accuracy: 0.3400
# Epoch 149/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6347 - accuracy: 0.7956 - val_loss: 3.3257 - val_accuracy: 0.3500
# Epoch 150/150
# 3/3 [==============================] - 0s 52ms/step - loss: 1.6039 - accuracy: 0.8102 - val_loss: 3.3859 - val_accuracy: 0.3500

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN/LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN/LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the basic CNN model - using the model from the last epoch (Must get 70% or higher for full credit)

hybrid_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hyrbid CNN/LSTM model:',hybrid_score[1])
# Out:
# Test accuracy of the hyrbid CNN/LSTM model: 0.3656884729862213

# %% [markdown]
# This is a reasonabley well performing model, the validation accuracy (orange) is closely following the training accuracy (blue), so the model is not overfitting. Similar for the loss plot, the validation(orange) is following closely with the training loss (blue) and seems to be converging (going toward zero), may be better to train for more epochs to see further convergence.
#
# U shaped curve for the loss means we are overfitting.
